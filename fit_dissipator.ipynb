# %%
omega_diss_max = 19#Ghz
alpha_diss = 0.257 # Ghz
phi_0 = 76 # in uA

d = 0.001

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
dissipator_freq = lambda phi: (omega_diss_max - alpha_diss)*( (np.cos(np.pi*(phi+5)/(phi_0)))**2 +  d**2*(np.sin(np.pi*(phi+5)/(phi_0)))**2)**(1/4) +alpha_diss

# %%
# Flux values in units of Phi/Phi0
phi = np.linspace(-50, 50, 1000)

# Evaluate function
omega = dissipator_freq(phi)

# Plot
plt.figure(figsize=(7, 4))
plt.plot((phi+5)/76, omega, linewidth=2)
